# %%
import pandas as pd

# %%
adverse=pd.read_sas('data/NINDS/Toprimate/dataset_archive/adverse.sas7bdat')

# %%
adverse
# Out:
#          id         visit                         ae   aeseverity  aeserious  \
# 0       1.0  b'All Visit'              b'edema feet'  b'Moderate'        0.0
# 1       1.0  b'All Visit'            b'constipation'  b'Moderate'        0.0
# 2       1.0  b'All Visit'      b'left shoulder pain'    b'Marked'        0.0
# 3       1.0  b'All Visit'          b'fluid in lungs'    b'Marked'        1.0
# 4       1.0  b'All Visit'           b'sleeplessness'    b'Marked'        0.0
# ...     ...           ...                        ...          ...        ...
# 2222  294.0  b'All Visit'                 b'anxiety'  b'Moderate'        0.0
# 2223  294.0  b'All Visit'                    b'rash'      b'Mild'        0.0
# 2224  294.0  b'All Visit'           b'low potassium'      b'Mild'        0.0
# 2225  294.0  b'All Visit'  b'gastrointestinal upset'  b'Moderate'        0.0
# 2226  294.0  b'All Visit'              b'congestion'      b'Mild'        0.0
#
# ...

# %%
als.columns
# Out:
# Index(['study_id', 'Visit_Name', 'Form_Name', 'diag_1', 'diag_2', 'diag_3',
#        'bulbar_umn', 'bulbar_clinical', 'bulbar_emg', 'cervical_umn',
#        'cervical_clinical', 'cervical_emg', 'thoracic_umn',
#        'thoracic_clinical', 'thoracic_emg', 'lumbar_umn', 'lumbar_clinical',
#        'lumbar_emg', 'criteria', 'stage', 'sequence', 'age_at_BASELINE',
#        'age_at_DATE_COMPLETED', 'age_at_VISIT_DATE'],
#       dtype='object')
